# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## ToDo
# 1. Have a look at the following dataset: [dsm-beuth-edl-demodata-orig](https://github.com/edlich/eternalrepo/blob/master/DS-WAHLFACH/dsm-beuth-edl-demodata-dirty.csv)
# 2. Write a Python / Panda Script which 'cleans' this data set.
# 3. Justify your actions in the respective notebook or python script you provide as a solution (link, file, kaggle repo, etc.).
# 4. The original dataset does not necessarily have to be created. A proper strategy / good arguments are more important. Value: 5 points.

# %% [markdown]
# ### 1. Load data directly via URL import into pandas data frame

# %%
url = 'https://github.com/edlich/eternalrepo/raw/master/DS-WAHLFACH/dsm-beuth-edl-demodata-dirty.csv'

# %%
df = pd.read_csv(url, error_bad_lines = False)
df.sample(10)
# Out:
#       id           full_name first_name    last_name  \
# 14  15.0           Eden Wace       Eden         Wace
# 10  11.0        Palm Domotor       Palm      Domotor
# 18  19.0      Clair Skillern      Clair     Skillern
# 19  20.0     Mathew Addicott     Mathew     Addicott
# 7    8.0        Jorge Tarney      Jorge       Tarney
# 17   NaN                 NaN        NaN          NaN
# 6    7.0      Franz Castello      Franz     Castello
# 16  17.0     Tobias Sherburn     Tobias     Sherburn
# 12  13.0      Modestia Keble   Modestia        Keble
# 8    9.0  Eunice Blakebrough     Eunice  Blakebrough
#
#                              email  gender  age
# 14             ewacee@marriott.com  Female   16
# 10             pdomotora@github.io    Male    6
# 18              cskillerng@nih.gov    Male  -78
# 19  maddicotth@acquirethisname.com    Male   65
# 7                  jtarney7@ft.com    Male   77
# 17                             NaN     NaN  NaN
# 6              fcastello6@1688.com    Male   25
# 16         tsherburnf@facebook.com    Male    2
# 12                 mkeblec@cmu.edu  Female   91
# 8           eblakebrough8@sohu.com  Female   45

# %% [markdown]
# ### 2. Display some basic information & statistical infos

# %%
df.index, df.columns
# Out:
# (RangeIndex(start=0, stop=23, step=1),
#  Index(['id', 'full_name', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object'))

# %%
df[df.columns[1:]].describe()
# Out:
#         full_name first_name last_name                email gender age
# count          21         21        21                   20     20  21
# unique         20         20        20                   19      2  17
# top     Eden Wace       Eden      Wace  ewacee@marriott.com   Male  16
# freq            2          2         2                    2     12   3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          20 non-null     float64
#  1   full_name   21 non-null     object
#  2   first_name  21 non-null     object
#  3   last_name   21 non-null     object
#  4   email       20 non-null     object
#  5   gender      20 non-null     object
#  6   age         21 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 1.4+ KB

# %% [markdown]
# ### 3. Cleaning Data
# - <s>check and correct character encoding</s>

# %% [markdown]
# ####  3.1. check and replace/drop NaN values if necessary
# - line 17 & 22 are empty and not needed
# - NaN values in "email", "gender", "age" are missing data and stay as NaN
# - NaN values in "id" need to be replaced with appropriate integer numbers

# %%
df[df.isna().any(axis=1)]
# Out:
#       id         full_name first_name last_name             email  gender  age
# 5    6.0      Hasty Perdue      Hasty    Perdue   hperdue5@qq.com     NaN   77
# 17   NaN               NaN        NaN       NaN               NaN     NaN  NaN
# 20  21.0  Kerianne Goacher   Kerianne   Goacher               NaN  Female   45
# 21   NaN     Maurits Shawl    Maurits     Shawl  mshawlj@dmoz.org    Male   72
# 22   NaN               NaN        NaN       NaN               NaN     NaN  NaN

# %%
df.drop(index=[17,22], inplace = True)

# %%
df['id'].fillna(value = 'mean_value', inplace = True)
df['id'].iloc[-1] = int(df['id'].iloc[-2]) + 1
df['id'] = df['id'].astype(int)

# %%
df.head(6)
# Out:
#    id        full_name first_name  last_name                   email  gender  \
# 0   1  Mariel Finnigan     Mariel   Finnigan     mfinnigan0@usda.gov  Female
# 1   2    Kenyon Possek     Kenyon     Possek       kpossek1@ucoz.com    Male
# 2   3   Lalo Manifould       Lalo  Manifould     lmanifould2@pbs.org    Male
# 3   4   Nickola Carous    Nickola     Carous       ncarous3@phoca.cz    Male
# 4   5    Norman Dubbin     Norman     Dubbin  ndubbin4@wikipedia.org    Male
# 5   6     Hasty Perdue      Hasty     Perdue         hperdue5@qq.com     NaN
#
#   age
# 0  60
# 1  12
# 2  26
# 3   4
# 4  17
# 5  77

# %% [markdown]
# #### 3.2 Convert numerical columns into appropriate data type
# - columns 'age',  'id' will be converted from 'object' type to 'int'
# - for 'age' column the absolut int value will be applied, due to a negative entry
# - a string in the 'age' column will be replaced by NaN, as 'old' is not accurate enough

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce').astype('Int64').fillna(0).astype('int')
df['age'] = df['age'].astype(int)

# %%
df['age'] = abs(df['age'])

# %%
df.iloc[16:19]
# ist 'Clair' wirklich 'male'? Hmm... why not.
# Out:
#     id        full_name first_name last_name                           email  \
# 16  17  Tobias Sherburn     Tobias  Sherburn         tsherburnf@facebook.com
# 18  19   Clair Skillern      Clair  Skillern              cskillerng@nih.gov
# 19  20  Mathew Addicott     Mathew  Addicott  maddicotth@acquirethisname.com
#
#    gender  age
# 16   Male    2
# 18   Male   78
# 19   Male   65

# %%
# numpy NaN are not the same as the NaN values in that data, 
# so I replace the missing age data with the same NaN value as already pressent in the data
df['email'].iloc[19], np.nan, df['email'].iloc[19] == np.nan
# Out:
# (nan, nan, False)

# %%
na = df['email'].iloc[19]
df['age'] = df['age'].replace(0, na)    # -->    int values turn into float, when re-entering NaN value

# %%
df.iloc[8:11]
# Out:
#     id              full_name  first_name    last_name  \
# 8    9     Eunice Blakebrough      Eunice  Blakebrough
# 9   10  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11           Palm Domotor        Palm      Domotor
#
#                      email  gender   age
# 8   eblakebrough8@sohu.com  Female  45.0
# 9   kfrankcombe9@slate.com    Male   NaN
# 10     pdomotora@github.io    Male   6.0

# %% [markdown]
# #### 3.3 Check and drop duplicates

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# #### 3.4 Check and replace index if necessary
# - <s>replace index with id column</s>
# - replace index with continuous number

# %%
df.reset_index(drop=True, inplace=True)
df.tail()
# Out:
#     id         full_name first_name last_name                           email  \
# 16  17   Tobias Sherburn     Tobias  Sherburn         tsherburnf@facebook.com
# 17  19    Clair Skillern      Clair  Skillern              cskillerng@nih.gov
# 18  20   Mathew Addicott     Mathew  Addicott  maddicotth@acquirethisname.com
# 19  21  Kerianne Goacher   Kerianne   Goacher                             NaN
# 20  22     Maurits Shawl    Maurits     Shawl                mshawlj@dmoz.org
#
#     gender   age
# 16    Male   2.0
# 17    Male  78.0
# 18    Male  65.0
# 19  Female  45.0
# 20    Male  72.0

# %% [markdown]
# #### 3.5 Check if full_name maches first_nam + last_name

# %%
df['check_name'] = df['first_name'] + " " + df['last_name']

# %%
df['check_name'] == df['full_name']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# dtype: bool

# %%
df.drop(columns='check_name', inplace=True)

# %% [markdown]
# #### 3.6 Beautify column names

# %%
cols = df.columns
new_cols = [c.capitalize().replace('_', ' ') for c in cols]
df.columns = new_cols

# %% [markdown]
# ## -- Finish line --

# %%
df
# Out:
#     Id              Full name  First name    Last name  \
# 0    1        Mariel Finnigan      Mariel     Finnigan
# 1    2          Kenyon Possek      Kenyon       Possek
# 2    3         Lalo Manifould        Lalo    Manifould
# 3    4         Nickola Carous     Nickola       Carous
# 4    5          Norman Dubbin      Norman       Dubbin
# 5    6           Hasty Perdue       Hasty       Perdue
# 6    7         Franz Castello       Franz     Castello
# 7    8           Jorge Tarney       Jorge       Tarney
# 8    9     Eunice Blakebrough      Eunice  Blakebrough
# 9   10  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11           Palm Domotor        Palm      Domotor
# 11  12          Luz Lansdowne         Luz    Lansdowne
# 12  13         Modestia Keble    Modestia        Keble
# 13  14           Stacee Bovis      Stacee        Bovis
# 14  15              Eden Wace        Eden         Wace
# 15  16              Eden Wace        Eden         Wace
# 16  17        Tobias Sherburn      Tobias     Sherburn
# 17  19         Clair Skillern       Clair     Skillern
# 18  20        Mathew Addicott      Mathew     Addicott
# 19  21       Kerianne Goacher    Kerianne      Goacher
# 20  22          Maurits Shawl     Maurits        Shawl
#
#                              Email  Gender   Age
# 0              mfinnigan0@usda.gov  Female  60.0
# 1                kpossek1@ucoz.com    Male  12.0
# 2              lmanifould2@pbs.org    Male  26.0
# 3                ncarous3@phoca.cz    Male   4.0
# 4           ndubbin4@wikipedia.org    Male  17.0
# 5                  hperdue5@qq.com     NaN  77.0
# 6              fcastello6@1688.com    Male  25.0
# 7                  jtarney7@ft.com    Male  77.0
# 8           eblakebrough8@sohu.com  Female  45.0
# 9           kfrankcombe9@slate.com    Male   NaN
# 10             pdomotora@github.io    Male   6.0
# 11     llansdowneb@theguardian.com  Female  16.0
# 12                 mkeblec@cmu.edu  Female  91.0
# 13           sbovisd@webeden.co.uk  Female  22.0
# 14             ewacee@marriott.com  Female  16.0
# 15             ewacee@marriott.com  Female  16.0
# 16         tsherburnf@facebook.com    Male   2.0
# 17              cskillerng@nih.gov    Male  78.0
# 18  maddicotth@acquirethisname.com    Male  65.0
# 19                             NaN  Female  45.0
# 20                mshawlj@dmoz.org    Male  72.0
